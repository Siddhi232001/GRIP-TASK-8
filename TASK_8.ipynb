# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhi232001/GRIP-TASK-8/blob/main/TASK_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Timeline Analysis - Covid 19 ***
#
# **COVID-19** is also known as Coronavirus disease 2019, is a contagious disease caused by the virus SARS-CoV-2. The first known case was identified in Wuhan, China, in December 2019. The disease quickly spread worldwide, resulting in the COVID-19 pandemic.
#
# This Timeline Analysis shows the spread of Covid-19 cases in Asia, Europe, BRICS etc. Identifying different patterns and possible reasons helping Covid-19 spread with the basic as well as advanced charts
#
# The following code is executed by **Siddhi Kelshikar**.

# %% [markdown]
# **STEP 1. Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# %% [markdown]
# **STEP 2: Reading Data**

# %%
data = pd.read_csv('/content/owid-covid-data.csv')
data.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan   1/3/2020          NaN        0.0
# 1      AFG      Asia  Afghanistan   1/4/2020          NaN        0.0
# 2      AFG      Asia  Afghanistan   1/5/2020          NaN        0.0
# 3      AFG      Asia  Afghanistan   1/6/2020          NaN        0.0
# 4      AFG      Asia  Afghanistan   1/7/2020          NaN        0.0
# 5      AFG      Asia  Afghanistan   1/8/2020          NaN        0.0
# 6      AFG      Asia  Afghanistan   1/9/2020          NaN        0.0
# 7      AFG      Asia  Afghanistan  1/10/2020          NaN        0.0
# 8      AFG      Asia  Afghanistan  1/11/2020          NaN        0.0
# 9      AFG      Asia  Afghanistan  1/12/2020          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# ...

# %%
data.tail(10)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 72982      CUB  North America     Cuba  6/10/2020       2205.0        5.0
# 72983      CUB  North America     Cuba  6/11/2020       2211.0        6.0
# 72984      CUB  North America     Cuba  6/12/2020       2219.0        8.0
# 72985      CUB  North America     Cuba  6/13/2020       2233.0       14.0
# 72986      CUB  North America     Cuba  6/14/2020       2238.0        5.0
# 72987      CUB  North America     Cuba  6/15/2020       2248.0       10.0
# 72988      CUB  North America     Cuba  6/16/2020       2262.0       14.0
# 72989      CUB  North America     Cuba  6/17/2020       2273.0       11.0
# 72990      CUB  North America     Cuba  6/18/2020       2280.0        7.0
# 72991      CUB  North America     Cuba  6/19/2020       2295.0       15.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data.shape
# Out:
# (72992, 67)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72992 entries, 0 to 72991
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    72992 non-null  object
#  1   continent                                   70187 non-null  object
#  2   location                                    72992 non-null  object
#  3   date                                        72992 non-null  object
#  4   total_cases                                 68350 non-null  float64
#  5   new_cases                                   72952 non-null  float64
#  6   new_cases_smoothed                          72687 non-null  float64
#  7   total_deaths                                65682 non-null  float64
#  8   new_deaths                                  72959 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  6.835000e+04  7.295200e+04        7.268700e+04  6.568200e+04
# mean   4.210930e+06  7.031960e+03        7.057135e+03  4.373565e+04
# std    2.443602e+07  1.079140e+05        1.043620e+05  1.832595e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    8.171000e+03  0.000000e+00        7.140000e-01  1.130000e+02
# 50%    6.260800e+04  3.000000e+00        2.485700e+01  8.330000e+02
# 75%    5.831990e+05  2.390000e+02        4.226430e+02  1.000800e+04
# max    3.007096e+08  7.213802e+06        6.109825e+06  1.635303e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  72959.000000         72694.000000             68350.000000
# mean      46.465193            46.633625             94663.928746
# std      284.343723           275.251139            140496.000630
# min        0.000000             0.000000                 0.000000
# ...

# %%
data.nunique()
# Out:
# iso_code                                      53
# continent                                      6
# location                                      53
# date                                        1407
# total_cases                                34798
#                                            ...
# population                                    53
# excess_mortality_cumulative_absolute        2072
# excess_mortality_cumulative                 1548
# excess_mortality                            1714
# excess_mortality_cumulative_per_million     2076
# Length: 67, dtype: int64

# %%
data.isnull().sum()
# Out:
# iso_code                                       0
# continent                                   2805
# location                                       0
# date                                           0
# total_cases                                 4642
#                                            ...
# population                                     1
# excess_mortality_cumulative_absolute       70916
# excess_mortality_cumulative                70916
# excess_mortality                           70916
# excess_mortality_cumulative_per_million    70916
# Length: 67, dtype: int64

# %%
data.continent.value_counts()
# Out:
# Africa           18200
# North America    16969
# Asia             12603
# Europe           11208
# South America     7007
# Oceania           4200
# Name: continent, dtype: int64

# %% [markdown]
# STEP 3: Analyzing dataset

# %%
# Continents in terms of occurence of covid cases on basis of iso_codes
data.continent.value_counts()[0:10]
# Out:
# Africa           18200
# North America    16969
# Asia             12603
# Europe           11208
# South America     7007
# Oceania           4200
# Name: continent, dtype: int64

# %%
# Analyzing cases worldwide
dataset = data[data['date']=='2020-11-15']
dataset = dataset[~dataset['location'].isin(['World','International'])]
dataset.head(10)
# Out:
# Empty DataFrame
# ...

# %%
# Looking at different locations
data["location"].value_counts()
# Out:
# Argentina                          1407
# Bulgaria                           1405
# Asia                               1405
# Afghanistan                        1403
# Croatia                            1403
# Cayman Islands                     1400
# Brazil                             1400
# British Virgin Islands             1400
# Brunei                             1400
# Burkina Faso                       1400
# Burundi                            1400
# Cambodia                           1400
# Cameroon                           1400
# Canada                             1400
# Cape Verde                         1400
# Chad                               1400
# Central African Republic           1400
# Bosnia and Herzegovina             1400
# Chile                              1400
# China                              1400
# Colombia                           1400
# Comoros                            1400
# Congo                              1400
# ...

# %% [markdown]
# **STEP 4: India's covid cases**

# %%
india=data[data["location"]=="India"]
india.head()
# Out:
# Empty DataFrame
# ...

# %%
# Data Visualization of India's covid cases

sns.set(rc={"figure.figsize":(10,5)})
sns.lineplot(x="date",y="total_cases",data=india)
plt.show()

# %%
# Data Visualization of India's last five days covid cases
india_last_5_days=india.tail()

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.lineplot(x="date",y="total_cases", data=india_last_5_days)
plt.show()

# %%
# Total test per day

sns.set(rc={"figure.figsize":(10,5)})
sns.lineplot(x="date",y="total_cases", data=india)
plt.show()

# %%
# Total test last 5 days
sns.set(rc={"figure.figsize":(10,5)})
sns.lineplot(x="date",y="total_cases", data=india_last_5_days)
plt.show()

# %% [markdown]
# **STEP 5: Russia's covid cases**

# %%
Russia = data[data["location"]=="Russia"]

# %%
Russia.head()
# Out:
# Empty DataFrame
# ...

# %%
Russia.tail()
# Out:
# Empty DataFrame
# ...

# %%
#Data visualization of Russia's last five days covid cases
Russia_last_5_days=Russia.tail()

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.lineplot(x="date",y="total_cases", data=Russia_last_5_days)
plt.show()

# %% [markdown]
# **STEP 6: Cases of India, China and Japan**

# %%
india_china_japan=data[(data["location"]=="India") | (data["location"]=="China") | (data["location"]=="Japan")]

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.barplot(x="location",y="total_cases", data=india_china_japan, hue="date")
plt.show()

# %% [markdown]
# **STEP 7: Cases of Germany and Spain **

# %%
germany_spain=data[(data["location"]=="Germany") | (data["location"]=="Spain")]

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.barplot(x="location",y="total_cases", data=germany_spain, hue="date")
plt.show()

# %%
# Getting Last day data

last_day_cases=data[(data["date"]=="2020-12-18")]
last_day_cases
# Out:
# Empty DataFrame
# ...

# %%
# Sorting date w.r.t to total cases

max_cases_country=last_day_cases.sort_values(by="total_cases", ascending=False)
max_cases_country
# Out:
# Empty DataFrame
# ...

# %%
# Top 5 countries with maximum case
max_cases_country[1:6]
# Out:
# Empty DataFrame
# ...
